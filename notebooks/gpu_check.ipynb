# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
print('Num GPUs Available:', len(gpus))
if gpus:
    print('GPU details:', gpus)
else:
    print('No GPU detected. Ensure proper CUDA/cuDNN installation.')
